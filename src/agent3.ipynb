# %%
import ollama
import json
import time
import requests
from typing import List, Dict, Set
import pandas as pd

AGENT_3 = 'mistral'
BEARER_TOKEN = "insert your semantic scholar key here"
SS_HEADERS = {"Authorization": f"Bearer {BEARER_TOKEN}"}

# %%
with open("output/agent2_ideas.json", "r") as f:
    data = json.load(f)

df = pd.DataFrame(data)

# %%
# keep only rows where title is nonempty
df = df[df['title'].str.strip().astype(bool)]

# (optional) reset the index to go 0…N-1 again
df = df.reset_index(drop=True)

# %%
df.head(20)
# Out:
#                                                 title  \
# 0       Arctic Anomaly Detection with Computer Vision
# 1            Climate Resilience Prediction using GANs
# 2        Sea Level Rise Prediction with Deep Learning
# 3                 Renewable Energy Output Forecasting
# 4   Climate Policy Optimization with Reinforcement...
# 5   Sustainable Deep Learning Models for Energy Ef...
# 6        Climate Data Fusion for Enhanced Predictions
# 7                 AI-Driven Carbon Footprint Analysis
# 8   Geoengineering Impact Assessment with Simulations
# 9   Climate Tipping Points Prediction with Predict...
# 10  Machine Learning for Climate Adaptation Strate...
# 11  Environmental Predictive Modeling with Transfo...
# 12                  Climate Justice Analysis using AI
# 13  Machine Learning-Based Weather Forecasting for...
# 14  Climate Model Uncertainty Quantification with ...
# 15  Climate Decision Support Systems with Multi-Ag...
# 16       Sustainable Development Optimization with AI
# 17  AI for Climate Governance and Policy Implement...
# 18  Climate Informatics for Carbon Footprint Visua...
# 19   Climate Scenario Planning with Generative Models
#
#                                           description  \
# 0   A deep learning system that detects and classi...
# 1   Generative adversarial networks (GANs) simulat...
# 2   A deep learning model that forecasts regional ...
# 3   Machine learning algorithms predict solar and ...
# 4   Reinforcement learning models simulate and rec...
# 5   Designs energy-efficient deep learning archite...
# 6   A multimodal deep learning framework that fuse...
# 7   A deep learning system that tracks and predict...
# 8   Machine learning models simulate the environme...
# 9   Predictive analytics models identify early war...
# 10  AI systems tailor climate adaptation strategie...
# 11  Transformer-based models predict environmental...
# 12  AI tools assess climate justice by analyzing t...
# 13  Deep learning models predict hyper-local weath...
# 14  Bayesian deep learning techniques quantify unc...
# 15  Multi-agent RL systems simulate stakeholder in...
# 16  AI optimizes resource allocation for sustainab...
# 17  AI automates climate governance by analyzing c...
# 18  Deep learning models visualize carbon footprin...
# 19  Generative models simulate future climate scen...
#
#                                            data_needs  \
# 0   [Satellite imagery, Arctic climate data, histo...
# 1   [Historical climate data, urban/agricultural d...
# 2   [Ocean current measurements, satellite altimet...
# 3   [Weather forecasts, satellite imagery, energy ...
# 4   [Climate policy datasets, economic indicators,...
# 5   [Model performance metrics, energy consumption...
# 6   [Satellite data, ground sensor networks, ocean...
# 7   [Emissions inventories, supply chain data, ene...
# 8   [Atmospheric chemistry data, climate simulatio...
# 9   [Historical climate records, tipping point ind...
# 10  [Vulnerability assessments, socio-economic dat...
# 11  [Satellite imagery, species occurrence records...
# 12  [Demographic data, climate impact assessments,...
# 13  [Weather station data, soil moisture measureme...
# 14  [Climate model outputs, parameter sensitivity ...
# 15  [Stakeholder behavior data, climate action sce...
# 16  [Resource use data, sustainability metrics, ec...
# 17  [Policy compliance data, emissions reports, in...
# 18  [Carbon emissions data, supply chain logs, ene...
# 19  [Climate scenario datasets, socio-economic pro...
#
#                                               idea_id
# 0     8_arctic_anomaly_detection_with_computer_vision
# 1          9_climate_resilience_prediction_using_gans
# 2     10_sea_level_rise_prediction_with_deep_learning
# 3              11_renewable_energy_output_forecasting
# 4   12_climate_policy_optimization_with_reinforcem...
# 5   13_sustainable_deep_learning_models_for_energy...
# 6     14_climate_data_fusion_for_enhanced_predictions
# 7              15_ai-driven_carbon_footprint_analysis
# 8   16_geoengineering_impact_assessment_with_simul...
# 9   17_climate_tipping_points_prediction_with_pred...
# 10  18_machine_learning_for_climate_adaptation_str...
# 11  19_environmental_predictive_modeling_with_tran...
# 12               20_climate_justice_analysis_using_ai
# 13  21_machine_learning-based_weather_forecasting_...
# 14  22_climate_model_uncertainty_quantification_wi...
# 15  23_climate_decision_support_systems_with_multi...
# 16    24_sustainable_development_optimization_with_ai
# 17  25_ai_for_climate_governance_and_policy_implem...
# 18  26_climate_informatics_for_carbon_footprint_vi...
# 19  27_climate_scenario_planning_with_generative_m...

# %%
ideas = df["title"].tolist()
dict_of_title_and_idea_ids = df.set_index("title")["idea_id"].to_dict()

# %%
def query_ollama_model(model_name, prompt_for_keywords):
    try:
        print(f"Sending prompt to Ollama model: {model_name}...")
        response = ollama.chat(
            model=model_name,
            messages=[
                {
                    'role': 'user',
                    'content': prompt_for_keywords,
                },
            ]
        )
        print("Received response from Ollama.")
        return response['message']['content']
    except Exception as e:
        return f"An error occurred while communicating with Ollama: {e}"

def get_ollama_response(prompt_for_keywords,model_name):

    # --- Execution ---
    print(f"Requesting keywords from Ollama for model: {model_name}...")
    
    keywords_response = query_ollama_model(model_name, prompt_for_keywords)
    return keywords_response

# %%
key_ideas_generation_prompt_1 = f"""
You are an AI Research Synthesizer. Your primary objective is to analyze a collection of `n` research paper abstracts, all related to a common theme or a specific research idea within <Topic>Climate Change and Deep Learning</Topic>. Your task is to distill these abstracts into a single, unified set of key bullet points that capture the holistic picture and core gist of the combined information. These points should highlight the most significant, recurring, or foundational insights that emerge when considering all abstracts together.

**Instructions for Synthesizing Collective Key Points:**

1.  **Comprehensive Review:** Thoroughly read and analyze ALL `n` provided abstracts to understand the full scope of information.
2.  **Identify Overarching Themes & Connections:** Look for:
    *   Common research questions, objectives, or problems addressed across multiple abstracts.
    *   Recurring methodologies, techniques, or datasets employed.
    *   Converging findings or consistent conclusions that appear in several abstracts.
    *   Complementary information where different abstracts contribute unique pieces to a larger puzzle.
    *   The overall narrative or argument these abstracts collectively support regarding the central theme or idea.
3.  **Synthesize, Don't Just Aggregate:** Your goal is not to pick one point from each abstract. Instead, formulate new summary points that represent the *synergistic understanding* gained from all abstracts. A single bullet point might draw from concepts mentioned in multiple abstracts.
4.  **Focus on the Core Gist:** The bullet points should represent the most critical and impactful insights that define the collective evidence or understanding presented. What are the absolute must-know takeaways if someone were to understand the essence of these `n` abstracts as a whole?
5.  **Conciseness and Clarity:** Each bullet point should be a clear, concise phrase or a short, impactful sentence.
6.  **Number of Points:** Aim for a focused list of 5-7 key bullet points in total for the entire set of abstracts. The exact number can vary based on the richness and diversity of the input, but the goal is a high-level synthesis.
7.  **Holistic Perspective:** The final list of bullet points should read as a coherent summary of the combined knowledge, not a disjointed collection.
8.  **Output Formatting (CRUCIAL):**
    *   Provide a single, unified list of bullet points.
    *   Use standard bullet characters (e.g., `*`, `-`, or `•`).
    *   Do NOT provide separate summaries for each abstract.
    *   Do NOT include any introductory phrases (e.g., "Here are the synthesized key points...") or concluding remarks, other than the single bulleted list.

**Input Abstracts:**

You will now be provided with `n` abstracts. Please process them *collectively* according to the instructions above to generate a *single list* of synthesized key points.
--
"""

key_ideas_generation_prompt_2 = """
**Your Task:**
Generate a single, unified list of 5-7 key bullet points that synthesize the core gist and holistic picture from ALL `n` abstracts provided above. Adhere strictly to all instructions, especially regarding the synthesis approach and output formatting.
"""

# %%
def search_papers(query: str, limit: int = 3) -> List[Dict]:
    """Search for papers using the given query."""
    SEARCH_URL = "https://api.semanticscholar.org/graph/v1/paper/search"

    search_params = {
        "query": query,
        "limit": limit,
        "fields": "paperId,title,externalIds,abstract"
    }

    try:
        resp = requests.get(SEARCH_URL, params=search_params, headers=SS_HEADERS)
        resp.raise_for_status()
        return resp.json().get("data", [])
    except requests.exceptions.RequestException as e:
        print(f"Search error for query '{query}': {e}")
        return []


# ——— 4) Function to get paper abstract from different sources ———
def get_paper_abstract(paper: Dict) -> str:
    """Attempt to get abstract from Semantic Scholar, then OpenAlex if needed."""
    # Check if we already have the abstract
    abstract = paper.get("abstract")
    if abstract:
        return abstract

    # If not, try to fetch it from Semantic Scholar
    DETAIL_URL = "https://api.semanticscholar.org/graph/v1/paper/"
    pid = paper["paperId"]

    try:
        detail_params = {"fields": "abstract,externalIds"}
        r = requests.get(DETAIL_URL + pid, params=detail_params, headers=SS_HEADERS)
        r.raise_for_status()
        data = r.json()
        abstract = data.get("abstract")

        # If SS returned no abstract, try OpenAlex
        if not abstract:
            ext = data.get("externalIds") or paper.get("externalIds", {})
            oa_id = ext.get("OpenAlex") if ext else None

            if oa_id:
                oa_url = f"https://api.openalex.org/works/{oa_id}"
                oa_r = requests.get(oa_url)
                if oa_r.ok:
                    oa_data = oa_r.json()
                    inv_idx = oa_data.get("abstract_inverted_index") or {}
                    if inv_idx:
                        # Reconstruct plain text abstract from inverted index
                        pos_map = {}
                        for word, positions in inv_idx.items():
                            for pos in positions:
                                pos_map[pos] = word
                        # Build ordered list of words
                        abstract = " ".join(
                            pos_map[i] for i in range(len(pos_map))
                            if i in pos_map
                        )

        return abstract or "(no abstract available)"

    except requests.exceptions.RequestException as e:
        print(f"Error fetching abstract for paper {pid}: {e}")
        return "(error retrieving abstract)"


# ——— 5) Main function to run the entire process ———
def main():

    # Track unique papers by ID to avoid duplicates
    unique_papers: Dict[str, Dict] = {}
    papers_per_query: Dict[str, Set[str]] = {}
    idea_bullet_Points = {}
    # Process each permutation
    for i, query in enumerate(ideas):
        print(f"Processing IDEA {i + 1}/{len(ideas)}: {query}")

        # Search for papers
        papers = search_papers(query)
        papers_per_query[query] = set()
        all_abstracts = ""
        for idx,paper in enumerate(papers):
            pid = paper["paperId"]
            papers_per_query[query].add(pid)

            # Skip if we already have this paper
            if pid in unique_papers:
                continue

            # Get the abstract if not already included
            if not paper.get("abstract"):
                paper["abstract"] = get_paper_abstract(paper)
            print(f"Found paper: {paper['title']} (ID: {pid})")
            all_abstracts += f"**Abstract {idx+1}:**\n {paper['abstract']}\n"
            print("=" * 80)
            unique_papers[pid] = paper
            time.sleep(1)
        key_ids_prompt_to_ollma = key_ideas_generation_prompt_1 + all_abstracts + key_ideas_generation_prompt_2
        bullet_points = get_ollama_response(key_ids_prompt_to_ollma, AGENT_3)

        idea_bullet_Points[dict_of_title_and_idea_ids[query]] = bullet_points
        time.sleep(1)
    with open(f"output/task3_idea_bullet_points.json", "w") as f:
        json.dump(idea_bullet_Points, f, indent=4)
    # Save the idea bullet points to a CSV file
    df = pd.DataFrame(idea_bullet_Points.items(), columns=["idea_id", "bullet_points"])
    df.to_csv(f"output/task3_idea_bullet_point.csv", index=False)
    

if __name__ == "__main__":
    main()
# Out:
# Processing IDEA 1/20: Arctic Anomaly Detection with Computer Vision
# Found paper: Pedestrian Equipment Anomaly Detection with Computer Vision in Warehouses (ID: 734e724119e8a7920ef161c1b814bb492d87e261)
# ================================================================================
# Found paper: Anomaly Detection in Industrial Quality Control with Computer Vision and Deep Learning (ID: 6554eb2d0b65a575d416f5c3de98c5201ec877ed)
# ================================================================================
# Found paper: Research on the Application of Deep Learning-Based Computer Vision in Anomaly Detection in Communication Networks (ID: 7b13d8795a36c6f09e172836331435af4630ab35)
# ================================================================================
# Requesting keywords from Ollama for model: mistral...
# Sending prompt to Ollama model: mistral...
# Received response from Ollama.
# Processing IDEA 2/20: Climate Resilience Prediction using GANs
# Found paper: AI-Driven Breeding Enhances Stress Tolerance in High-Elevation Extremophytes: A Proof-of-Concept Study with Cross-Component Validation (ID: cf4fa552dfd1a2f4e8b5f0d5426a9e381057cd41)
# ================================================================================
# Found paper: Crop yield prediction through machine learning: A path towards sustainable agriculture and climate resilience in Saudi Arabia (ID: ff63f36c2368714836dff87c4eb27a0733569763)
# ================================================================================
# Found paper: A Systematic Approach to Climate Resilience Assessment of Infrastructure Networks (ID: 1f029afd2ca80f6648f41e9a39f9e5f8544c228e)
# ================================================================================
# Requesting keywords from Ollama for model: mistral...
# Sending prompt to Ollama model: mistral...
# Received response from Ollama.
# Processing IDEA 3/20: Sea Level Rise Prediction with Deep Learning
# Found paper: Prediction of Submergence of Islands Due to Glacier Melting & Sea Level Rise using Deep Learning (ID: 08290f06311777fb57a2816e0695c1aca9f4523d)
# ================================================================================
# Found paper: Reducing Uncertainty in Sea-level Rise Prediction: A Spatial-variability-aware Approach (ID: db11c9d735b04731fe22bc14d3cbf2f47c72b948)
# ================================================================================
# Found paper: Prediction of Sea Level Using Double Data Decomposition and Hybrid Deep Learning Model for Northern Territory, Australia (ID: 06a95e5680dd994a5330852afaee24061683b9b7)
# ================================================================================
# Requesting keywords from Ollama for model: mistral...
# Sending prompt to Ollama model: mistral...
# Received response from Ollama.
# Processing IDEA 4/20: Renewable Energy Output Forecasting
# Search error for query 'Renewable Energy Output Forecasting': 429 Client Error:  for url: https://api.semanticscholar.org/graph/v1/paper/search?query=Renewable+Energy+Output+Forecasting&limit=3&fields=paperId%2Ctitle%2CexternalIds%2Cabstract
# Requesting keywords from Ollama for model: mistral...
# Sending prompt to Ollama model: mistral...
# Received response from Ollama.
# Processing IDEA 5/20: Climate Policy Optimization with Reinforcement Learning
# Found paper: Comparing Deep Reinforcement Learning Methods for HVAC System Optimization with Forecast Parameters Over Various Time Periods (ID: 14292965803ea834a654616f3701c144294573c5)
# ================================================================================
# Found paper: Deep Reinforcement Learning-Based Joint Low-Carbon Optimization for User-Side Shared Energy Storage–Distribution Networks (ID: fc9dd0f1e07d4852819c506a484ebcf55cff28f4)
# ================================================================================
# Found paper: Multi-Agent Reinforcement Learning Simulation for Environmental Policy Synthesis (ID: f1e9690f404fdd6c55774183e6676e02feb326a2)
# ================================================================================
# Requesting keywords from Ollama for model: mistral...
# Sending prompt to Ollama model: mistral...
# Received response from Ollama.
# Processing IDEA 6/20: Sustainable Deep Learning Models for Energy Efficiency
# Found paper: Enhancing Building Energy Efficiency with IoT-Driven Hybrid Deep Learning Models for Accurate Energy Consumption Prediction (ID: f7bdc001a2fe4b4c2340b0bbd277aa7b96c41d41)
# ================================================================================
# Found paper: Smart Prediction Models for Energy Efficiency in Smart Residential Buildings: A Deep Learning Approach (ID: 3b643dd8c62d57d270c70b4a1b4f03f2dd9a1d41)
# ================================================================================
# Found paper: A Deep Learning Approach for Sustainable and Secure Operations of Cloud Data Centres for Optimising the Energy Efficiency (ID: 6feef3a9b4282cb2e9cd08b809156bbb04cc46ca)
# ================================================================================
# Requesting keywords from Ollama for model: mistral...
# Sending prompt to Ollama model: mistral...
# Received response from Ollama.
# Processing IDEA 7/20: Climate Data Fusion for Enhanced Predictions
# Found paper: Research on Wind Speed Prediction Method Based on Feature Fusion (ID: 57961dfd50acbf5394f56ed8be40522494f91315)
# ================================================================================
# Found paper: ILF-LSTM: enhanced loss function in LSTM to predict the sea surface temperature (ID: bbc9ecfcf6193f68abfa9635641616d090e12b6a)
# ================================================================================
# Found paper: EcoLight+: a novel multi-modal data fusion for enhanced eco-friendly traffic signal control driven by urban traffic noise prediction (ID: f28618ba25f372cefa6de3d3d70bec72b7faa176)
# ================================================================================
# Requesting keywords from Ollama for model: mistral...
# Sending prompt to Ollama model: mistral...
# Received response from Ollama.
# Processing IDEA 8/20: AI-Driven Carbon Footprint Analysis
# Found paper: Comparative Analysis of Sustainability, Carbon Footprint, and AI's Role in Reducing Emissions Across AWS, Azure, and Google Cloud (ID: cd348873cf85100d2d4a6449a339bd20e0b2f36c)
# ================================================================================
# Found paper: Carbon Footprint Accounting Driven by Large Language Models and Retrieval-augmented Generation (ID: 3eeb6829db131c59558bff33f05aa26891245680)
# ================================================================================
# Found paper: AI-Driven Data Analysis of Quantifying Environmental Impact and Efficiency of Shape Memory Polymers (ID: 1f7da87942b2f58a3437e412d0bff7da2b6cb8e3)
# ================================================================================
# Requesting keywords from Ollama for model: mistral...
# Sending prompt to Ollama model: mistral...
# Received response from Ollama.
# Processing IDEA 9/20: Geoengineering Impact Assessment with Simulations
# Found paper: Assessment of solar geoengineering impact on precipitation and temperature extremes in the Muda River Basin, Malaysia using CMIP6 SSP and GeoMIP6 G6 simulations. (ID: bc2c2b6c64bfdca7288320229c95b899da5d7891)
# ================================================================================
# Found paper: Thermosteric and dynamic sea level under solar geoengineering (ID: 789026b9b36cdc23be72e43ea2fbd041b7a90298)
# ================================================================================
# Found paper: Climate econometric models indicate solar geoengineering would reduce inter-country income inequality (ID: 19a0b014312828fcbba2a2afa32ff1a7303713b7)
# ================================================================================
# Requesting keywords from Ollama for model: mistral...
# Sending prompt to Ollama model: mistral...
# Received response from Ollama.
# Processing IDEA 10/20: Climate Tipping Points Prediction with Predictive Analytics
# Found paper: Climate Tipping Points (ID: 0095d5cde4536726133fddcde00ed1abe9db7230)
# ================================================================================
# Found paper: Prediction of tipping points in hierarchical and climate networks: Microtransitions and other precursors (ID: 8934d4479ed3bedcd29139e4f36943130edb3aa7)
# ================================================================================
# Found paper: Using Machine Learning to Anticipate Tipping Points and Extrapolate to Post-Tipping Dynamics of Non-Stationary Dynamical Systems (ID: ebe23db676b2b9a27f7eecb29ec0fe89a5dc0618)
# ================================================================================
# Requesting keywords from Ollama for model: mistral...
# Sending prompt to Ollama model: mistral...
# Received response from Ollama.
# Processing IDEA 11/20: Machine Learning for Climate Adaptation Strategies
# Found paper: Tackling extreme urban heat: a machine learning approach to assess the impacts of climate change and the efficacy of climate adaptation strategies in urban microclimates (ID: 648dfceed6c39b6f5fe233a3b0010bf0f561992c)
# ================================================================================
# Found paper: Optimizing Agricultural Yields with Artificial Intelligence-Based Climate Adaptation Strategies (ID: 532bf0fc21c1e3298101521fe25e560872c76a99)
# ================================================================================
# Found paper: A Framework for Monitoring the Effectiveness of Ecosystem-Based Adaptation Strategies Using Internet of Things and Machine Learning Techniques (ID: 0853d0a59b5487624869295e4112a21309ab1fb2)
# ================================================================================
# Requesting keywords from Ollama for model: mistral...
# Sending prompt to Ollama model: mistral...
# Received response from Ollama.
# Processing IDEA 12/20: Environmental Predictive Modeling with Transformers
# Found paper: Secured Forest Fire Prediction Using Blockchain and CNN Transformers (ID: 8db7ca9f5f5296aacb6cbc15630cfbd0de7701ad)
# ================================================================================
# Found paper: Prion-ViT: Prions-Inspired Vision Transformers for Temperature prediction with Specklegrams (ID: dab2d74507057f0cfa6fb70477d93a9f0488ee99)
# ================================================================================
# Found paper: A Probabilistic Approach for Forecasting the Allowable Current of Oil-Immersed Transformers (ID: e07d5e4b6fbd1c121ba871a36616a88b290cec1a)
# ================================================================================
# Requesting keywords from Ollama for model: mistral...
# Sending prompt to Ollama model: mistral...
# Received response from Ollama.
# Processing IDEA 13/20: Climate Justice Analysis using AI
# Found paper: Assessing energy justice in climate change policies: an empirical examination of China's energy transition (ID: 7cdf33004494c28bafffb68922625e2c2cc8c70d)
# ================================================================================
# Found paper: Toward Cognitive Justice: Reconstructions of Climate Finance Governance in Fiji (ID: 4773b5306b6c512ffda5d067acfddc463fa4e2a2)
# ================================================================================
# Found paper: Ethical leadership and employee ethical behaviour: exploring dual-mediation paths of ethical climate and organisational justice: empirical study on Iraqi organisations (ID: 1cf84a34c8a061bac9f7418bbf63fee2a2fb77fc)
# ================================================================================
# Requesting keywords from Ollama for model: mistral...
# Sending prompt to Ollama model: mistral...
# Received response from Ollama.
# Processing IDEA 14/20: Machine Learning-Based Weather Forecasting for Agriculture
# Found paper: Machine Learning-based Weather Forecasting for Precision Agriculture: Model Development, Evaluation, and Predictive Insights (ID: 8145886f2c8d8f53fd02bfdc7bf55df036142de9)
# ================================================================================
# Found paper: Machine Learning-based Weather Prediction: A Comparative Study of Regression and Classification Algorithms (ID: d865a3f0da12160b32a3bca7cd1d66429c70e75e)
# ================================================================================
# Found paper: AN INTENSE SURVEY OF WEATHER FORECASTING BASED ON MACHINE LEARNING AND DEEP NEURAL NETWORK (ID: e8e462979c7dbce70d2020465b22157a0bf5914d)
# ================================================================================
# Requesting keywords from Ollama for model: mistral...
# Sending prompt to Ollama model: mistral...
# Received response from Ollama.
# Processing IDEA 15/20: Climate Model Uncertainty Quantification with Bayesian Neural Networks
# Search error for query 'Climate Model Uncertainty Quantification with Bayesian Neural Networks': 429 Client Error:  for url: https://api.semanticscholar.org/graph/v1/paper/search?query=Climate+Model+Uncertainty+Quantification+with+Bayesian+Neural+Networks&limit=3&fields=paperId%2Ctitle%2CexternalIds%2Cabstract
# Requesting keywords from Ollama for model: mistral...
# Sending prompt to Ollama model: mistral...
# Received response from Ollama.
# Processing IDEA 16/20: Climate Decision Support Systems with Multi-Agent Reinforcement Learning
# Search error for query 'Climate Decision Support Systems with Multi-Agent Reinforcement Learning': 429 Client Error:  for url: https://api.semanticscholar.org/graph/v1/paper/search?query=Climate+Decision+Support+Systems+with+Multi-Agent+Reinforcement+Learning&limit=3&fields=paperId%2Ctitle%2CexternalIds%2Cabstract
# Requesting keywords from Ollama for model: mistral...
# Sending prompt to Ollama model: mistral...
# Received response from Ollama.
# Processing IDEA 17/20: Sustainable Development Optimization with AI
# Found paper: The Role of Ecological Space Structure Optimization in Synergetic Sustainable Development: Evidence from the Guangdong–Hong Kong–Macao Greater Bay Area (ID: 5ca35f92914924dd91b9a74936118df26eb9a47b)
# ================================================================================
# Found paper: Optimization Method for Sustainable Development of Smart City Public Management Based on Big Data Analysis (ID: 454d2ccb7ce3e3231762565b2924acf81ee5e023)
# ================================================================================
# Found paper: AI-driven project optimization: A strategic framework for accelerating sustainable development outcomes (ID: 3e379f7e4c973161722babb278718b73e7458b95)
# ================================================================================
# Requesting keywords from Ollama for model: mistral...
# Sending prompt to Ollama model: mistral...
# Received response from Ollama.
# Processing IDEA 18/20: AI for Climate Governance and Policy Implementation
# Found paper: Synergy of Patent and Open-Source-Driven Sustainable Climate Governance under Green AI: A Case Study of TinyML (ID: ef0f06948edb7083a9d25eba8e79c29bd0b5f23c)
# ================================================================================
# Found paper: Anticipating the Challenges of AI in Climate Governance: An Urgent Dilemma for Democracies (ID: f42e9e3e68401bd4ce5848052c269b7118254e3a)
# ================================================================================
# Found paper: 6.A. Round table: Building a Public Health Innovation Ecosystem in the WHO European Region (ID: b7b409810c9ae613da46d73ebc3f2a062423d743)
# ================================================================================
# Requesting keywords from Ollama for model: mistral...
# Sending prompt to Ollama model: mistral...
# Received response from Ollama.
# Processing IDEA 19/20: Climate Informatics for Carbon Footprint Visualization
# Found paper: Examining Passenger Vehicle Miles Traveled and Carbon Emissions in the Boston Metropolitan Area (ID: 6d56a964507976734dabd6077fa09f07ffccef85)
# ================================================================================
# Found paper: Carbon Footprint Research Based on Input–Output Model—A Global Scientometric Visualization Analysis (ID: e28d400e2dc6702aa6e7ff44d3486d0f3e0563d0)
# ================================================================================
# Found paper: We can’t mitigate what we don’t monitor: using informatics to measure and improve healthcare systems’ climate impact and environmental footprint (ID: eac99ed0fcbcdbbd933f0736b3af6be92bec98cb)
# ================================================================================
# Requesting keywords from Ollama for model: mistral...
# Sending prompt to Ollama model: mistral...
# Received response from Ollama.
# Processing IDEA 20/20: Climate Scenario Planning with Generative Models
# Found paper: Generating high-resolution climatological precipitation data using SinGAN (ID: 4f16d93e3c6756c5e38090997e74cfbd94defa9e)
# ================================================================================
# Found paper: Cross-Correlated Scenario Generation for Renewable-Rich Power Systems Using Implicit Generative Models (ID: a16ec7be38e1369edbb46526cc4313edf8c59daf)
# ================================================================================
# Found paper: A Review of Solar Power Scenario Generation Methods with Focus on Weather Classifications, Temporal Horizons, and Deep Generative Models (ID: ee0412b62630a09c80f0972725c17b2374a22947)
# ================================================================================
# Requesting keywords from Ollama for model: mistral...
# Sending prompt to Ollama model: mistral...
# Received response from Ollama.
